# %%
import os
import scipy.io

# %%
os.chdir("/cellar/users/aklie/data/ml4gland/pubs/zhou15")

# %%
test_mat = scipy.io.loadmat('deepsea_train/test.mat')

# %%
test_mat["testdata"].shape
# Out:
# (455024, 919)

# %%
test_mat["testxdata"].shape
# Out:
# (455024, 4, 1000)
